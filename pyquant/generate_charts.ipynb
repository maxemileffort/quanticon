# %%
# This script will find the most recent CSV in pyquant/outputs,
# read the symbols, download historical data, generate candlestick charts,
# and save them to a single PDF.

import os
import glob
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import mplfinance as mpf
from matplotlib.backends.backend_pdf import PdfPages
import ta

# %%
def compute_qdqu_signals(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    # Calculate EMAs
    week_ema_indicator = ta.trend.EMAIndicator(close=df['Close'], window=7)
    line_ema_indicator = ta.trend.EMAIndicator(close=df['Close'], window=20)
    qtr_ema_indicator = ta.trend.EMAIndicator(close=df['Close'], window=90)

    df['week_ema'] = week_ema_indicator.ema_indicator()
    df['line_ema'] = line_ema_indicator.ema_indicator()
    df['qtr_ema'] = qtr_ema_indicator.ema_indicator()

    # EMA deltas
    df['week_delta'] = df['week_ema'] - df['week_ema'].shift(1)
    df['qtr_delta'] = df['qtr_ema'] - df['qtr_ema'].shift(1)

    # Direction flags
    df['week_up'] = df['week_delta'] > 0
    df['week_down'] = df['week_delta'] < 0
    df['qtr_up'] = df['qtr_delta'] > 0
    df['qtr_down'] = df['qtr_delta'] < 0

    # Entry signals
    df['bull_entry'] = df['week_down'].shift(1) & df['week_up'] & df['qtr_up']
    df['bear_entry'] = df['week_up'].shift(1) & df['week_down'] & df['qtr_down']

    return df

# %%
# 1. Find the most recent CSV file in pyquant/outputs
output_dir = './outputs'
csv_files = glob.glob(os.path.join(output_dir, '*.csv'))

if not csv_files:
    print("No CSV files found in the outputs directory.")

most_recent_csvs = sorted(csv_files, key=os.path.getmtime, reverse=True)[:8]
print(f"Using the most recent CSV file: {most_recent_csvs}")
# Out:
# Using the most recent CSV file: ['./outputs\\2025-05-24_month_down_week_up&month_up_week_down.csv', './outputs\\2025-05-24_qtr_down_week_up&qtr_up_week_down.csv', './outputs\\2025-05-23_qtr_up_week_down.csv', './outputs\\2025-05-23_qtr_down_week_up.csv']

# %%
# 2. Read the CSV
df = pd.DataFrame()
for f in most_recent_csvs:
    try:
        df = pd.concat([df, pd.read_csv(f, sep='|')])
    except Exception as e:
        print(f"Error reading CSV file: {e}")

# %%
# 3. Get all of the files in the column called 'symbol'
if 'symbol' not in df.columns:
    print("CSV file does not contain a 'symbol' column.")
print(df.columns)

symbols = set(df['symbol'].tolist())
print(f"Found {len(symbols)} symbols: {symbols}")
# Out:
# Index(['symbol', 'volume', 'price_to_earnings', 'forward_pe', 'peg_ratio',
#        'price_to_sales', 'price_to_book', 'price_to_cash',
#        'eps_growth_past_1y', 'eps_growth_next_1y', 'eps_growth_past_5y',
#        'eps_growth_next_5y', 'sales_growth_past_5y', 'price_to_free_cash_flow',
#        'earnings_date', 'dividend_yield', 'return_on_assets',
#        'return_on_equity', 'return_on_investment', 'long_term_debt_to_equity',
#        'debt_to_equity', 'gross_margin', 'operating_margin', 'profit_margin',
#        'current_ratio', 'quick_ratio', 'volume_avg', 'shares_outstanding',
#        'shares_float', 'short_ratio', 'insider_ownership',
#        'insider_ownership_change', 'institutional_ownership',
#        'institutional_ownership_change', 'Short Float',
#        'analyst_recommendation', 'volume_relative', 'price_change_1w',
#        'price_change_1m', 'price_change_3m', 'price_change_6m',
#        'price_change_1y', 'price_change_ytd', 'volatility_1w', 'volatility_1m',
#        'beta', 'gap', 'average_true_range', 'year_high_percent',
#        'year_low_percent', 'sma20_percent', 'sma50_percent', 'sma200_percent',
#        'rsi', 'Change from Open', 'name', 'country', 'sector', 'industry',
#        'market_cap', 'price', 'change_percent'],
#       dtype='object')
# Found 575 symbols: {'NAK', 'BLND', 'VSCO', 'AER', 'FSLR', 'DELL', 'CAH', 'ADBE', 'BE', 'NE', 'BMBL', 'SPXU', 'DBRG', 'CONI', 'HAFN', 'LZ', 'CFG', 'HEFA', 'JBGS', 'MBOT', 'TXN', 'SEE', 'ARCC', 'CSX', 'S', 'IEI', 'NFLX', 'XLU', 'BYON', 'ZTS', 'OBDC', 'QRVO', 'SCHR', 'BN', 'WBS', 'KVYO', 'SCO', 'RLX', 'DD', 'SKX', 'WBX', 'AMZN', 'ADSK', 'ADI', 'BWA', 'SCHG', 'RKT', 'SPTI', 'SPDN', 'ADNT', 'ACVA', 'COWZ', 'EWT', 'IJH', 'QQQM', 'SCHW', 'ACHR', 'PSN', 'C', 'SIRI', 'ILMN', 'FAST', 'VO', 'BA', 'EWH', 'THC', 'FLNC', 'K', 'NTRA', 'RWM', 'MRSN', 'TOST', 'XRAY', 'SOXL', 'REPL', 'AEVA', 'PLTR', 'SPYG', 'COIN', 'CNP', 'MU', 'FHN', 'SNV', 'XERS', 'HPQ', 'VLTO', 'AMD', 'FL', 'WYNN', 'EYE', 'VYX', 'EEM', 'RL', 'EIX', 'EOSE', 'TECS', 'PINC', 'CDNS', 'LESL', 'PRGO', 'ITUB', 'SPLG', 'ATI', 'LUV', 'SPOT', 'PSTG', 'ADMA', 'APH', 'WBD', 'SBLK', 'SHAK', 'SCHX', 'ETHT', 'EVGO', 'WBA', 'FTAI', 'SCHB', 'JNJ', 'MLCO', 'CLSK', 'BTU', 'ORCL', 'INFY', 'BSV', 'HE', 'RDFN', 'EPI', 'SSO', 'SMCI', 'DXCM', 'NTAP', 'BMY', 'NTNX', 'BTDR', 'PYPL', 'SDS', 'MGNI', 'SRLN', 'IP', 'UVIX', 'LMND', 'BBAI', 'DYN', 'NWSA', 'HYG', 'BHP', 'LUNR', 'RIOT', 'ST', 'LITE', 'IVV', 'HLT', 'EXPD', 'TSLR', 'AA', 'DOV', 'ING', 'SCHA', 'STWD', 'ROL', 'ARVN', 'UNP', 'DINO', 'GENI', 'BNDX', 'XLC', 'ECVT', 'EL', 'BROS', 'CHTR', 'UBS', 'CGDV', 'EPAM', 'LEGN', 'USHY', 'ESTC', 'GOTU', 'MMC', 'PSQ', 'APTV', 'AG', 'DIA', 'EXEL', 'IGM', 'IWD', 'XPO', 'ARKK', 'FAZ', 'PNC', 'IVVD', 'TSLY', 'BAI', 'CVI', 'XOP', 'SPHY', 'MLGO', 'SPGI', 'AMZU', 'ANGI', 'NVDA', 'SRTY', 'AHR', 'BB', 'OPTT', 'HNRG', 'SMH', 'TSM', 'JBLU', 'XLP', 'XAIR', 'LYFT', 'HCA', 'HAS', 'FNDX', 'DHT', 'MGA', 'JBI', 'ELAN', 'CLNE', 'VGIT', 'SMCX', 'CYH', 'TSLA', 'SWK', 'LRCX', 'SWKS', 'SOXS', 'LNT', 'DXD', 'LULU', 'CNH', 'KMI', 'GS', 'CONL', 'HON', 'ALMS', 'WEC', 'CWH', 'SW', 'NOG', 'SPMO', 'SHO', 'COHR', 'FLYW', 'SNDK', 'BLDP', 'GEO', 'ANET', 'DFAC', 'SBH', 'GEN', 'TOL', 'SN', 'SDOW', 'MPC', 'VOO', 'SGMO', 'RUM', 'SOXX', 'ACAD', 'SPY', 'SPXS', 'SCHV', 'HIMS', 'ENVX', 'ETHU', 'UPRO', 'TSLG', 'V', 'HSIC', 'KWEB', 'ATEC', 'VGSH', 'TSLL', 'TAK', 'SJNK', 'SPXL', 'JNK', 'MMM', 'ETH', 'INDA', 'HYLB', 'UMC', 'TSSI', 'MCHP', 'ALK', 'NEOG', 'DGRO', 'CGGR', 'ROIV', 'ICE', 'AQN', 'W', 'JETS', 'XLG', 'ACWV', 'GOGO', 'XBI', 'ASHR', 'MTB', 'VTIP', 'BSX', 'PONY', 'UNG', 'OKTA', 'XLY', 'XP', 'AMDL', 'NVDL', 'EMR', 'MBLY', 'RSP', 'BK', 'META', 'SOLV', 'CRBG', 'SNDX', 'NVD', 'EBS', 'LXP', 'XLK', 'ALGM', 'BOIL', 'DLR', 'LYV', 'BZ', 'TEL', 'COMM', 'GGB', 'MOS', 'RIVN', 'PUMP', 'INDI', 'CUK', 'TECL', 'VTI', 'BP', 'TSLT', 'CP', 'KO', 'PATH', 'CARR', 'MS', 'ASX', 'LVS', 'NSC', 'ACWI', 'IR', 'JANX', 'PBR', 'CAT', 'PHX', 'CNI', 'QID', 'FOUR', 'AXL', 'IOT', 'WRB', 'IBM', 'CG', 'PNR', 'ZGN', 'SPYI', 'APA', 'FLEX', 'BEN', 'EXTR', 'PBR-A', 'BDSX', 'EQT', 'GRAB', 'SDVY', 'GNL', 'RCL', 'RELY', 'CALF', 'SMTC', 'SPEM', 'DYNF', 'SHEL', 'DIS', 'VIG', 'MAT', 'TQQQ', 'WTI', 'FIVN', 'TTD', 'PINS', 'UAA', 'BAM', 'NAT', 'TSLQ', 'STM', 'MAGS', 'MDB', 'SUZ', 'OCUL', 'QSR', 'KD', 'TALO', 'DUHP', 'ITOT', 'TWLO', 'AMBP', 'PBF', 'SPCE', 'SHOP', 'NWL', 'ETHE', 'QQQI', 'RTX', 'SCHO', 'SHOT', 'RCAT', 'CORZ', 'CSTM', 'HPE', 'NOW', 'RIG', 'IWF', 'VTWO', 'GTM', 'VUZI', 'XLI', 'MSFT', 'QUAL', 'QLD', 'TSDD', 'QQQ', 'ONON', 'AMPX', 'CRON', 'TMUS', 'SO', 'ARBE', 'APG', 'APP', 'FSLY', 'AXP', 'DVAX', 'DTE', 'ASAN', 'UPWK', 'SQQQ', 'CDW', 'ARWR', 'IVW', 'DUK', 'IWR', 'SRAD', 'USFD', 'ULTY', 'COWG', 'FERG', 'CSCO', 'ICLN', 'NRG', 'CROX', 'UAMY', 'CIFR', 'VT', 'UBER', 'BTSG', 'PFGC', 'EWZ', 'NKE', 'NVT', 'RKLB', 'AM', 'EMXC', 'TEM', 'JQUA', 'DDOG', 'STT', 'ONDS', 'PLUG', 'SNY', 'AAOI', 'DT', 'SHY', 'DAL', 'STEP', 'ARM', 'ARRY', 'ITP', 'ADPT', 'LAC', 'CGNX', 'ROKU', 'SH', 'MTSR', 'NVDU', 'PL', 'XLB', 'ET', 'GM', 'HOG', 'ZIM', 'ADC', 'USB', 'SYF', 'HALO', 'CE', 'IAS', 'CNX', 'PRCH', 'SRPT', 'WPC', 'FOXA', 'CTSH', 'ETHA', 'HIG', 'NVDX', 'MRK', 'XYL', 'BBY', 'BKE', 'SBUX', 'IOVA', 'ILF', 'NXT', 'UA', 'CCL', 'BIZD', 'PVH', 'AAL', 'APPS', 'PCVX', 'ASML', 'VRT', 'TGTX', 'IWM', 'DAWN', 'VIPS', 'HIVE', ...

# %%
# 4. Create candlestick charts for each symbol
from datetime import datetime

today_str = datetime.today().strftime('%Y-%m-%d')
pdf_output_path = os.path.join(output_dir, f'{today_str}_charts_quqd.pdf')

with PdfPages(pdf_output_path) as pdf:
    for symbol in symbols:
        
        try:
            # Download historical data
            ticker = yf.Ticker(symbol)
            hist_data = ticker.history(period="1y", interval="1d")

            if hist_data.empty:
                print(f"No data found for {symbol}. Skipping.")
                continue
            
            hist_data = compute_qdqu_signals(hist_data)

            entry = hist_data.tail(5)[['bull_entry', 'bear_entry']].any().any()

            if not entry:
                continue

            print(f"Generating chart for {symbol}...")

            # Prepare additional plots
            apds = [
                mpf.make_addplot(hist_data['week_ema'], color='aqua', width=1.0),
                mpf.make_addplot(hist_data['line_ema'], color='green', width=1.1),
                mpf.make_addplot(hist_data['qtr_ema'], color='orange', width=1.0),
                mpf.make_addplot(hist_data['Low'].where(hist_data['bull_entry']), type='scatter', markersize=50, marker='^', color='lime'),
                mpf.make_addplot(hist_data['High'].where(hist_data['bear_entry']), type='scatter', markersize=50, marker='v', color='red'),
            ]

            # Plot with overlays
            fig, axes = mpf.plot(
                hist_data,
                type='candle',
                style='binancedark',
                title=f'{symbol}',
                ylabel='Price',
                addplot=apds,
                figscale=1.5,
                returnfig=True
            )

            # Add the figure to the PDF
            pdf.savefig(fig)
            plt.close(fig) # Close the figure to free up memory

        except Exception as e:
            print(f"Error generating chart for {symbol}: {e}")
            continue

print(f"Candlestick charts saved to {pdf_output_path}")
# Out:
# Generating chart for NAK...
# Generating chart for BLND...
# Generating chart for VSCO...
# Generating chart for AER...
# Generating chart for ADBE...
# Error generating chart for ADBE: zero-size array to reduction operation maximum which has no identity
# Generating chart for BE...
# Generating chart for NE...
# Error generating chart for NE: zero-size array to reduction operation maximum which has no identity
# Generating chart for CFG...
# Generating chart for HEFA...
# Generating chart for MBOT...
# Generating chart for SEE...
# Generating chart for CSX...
# Generating chart for S...
# Generating chart for IEI...
# Generating chart for ZTS...
# Generating chart for SCHR...
# Generating chart for SCO...
# Generating chart for DD...
# Generating chart for ADSK...
# Generating chart for BWA...
# Generating chart for RKT...
# Generating chart for SPTI...
# Generating chart for ACVA...
# Generating chart for COWZ...
# Generating chart for PSN...
# Generating chart for SIRI...
# Generating chart for ILMN...
# Generating chart for BA...
# Generating chart for THC...
# Generating chart for FLNC...
# Generating chart for K...
# Error generating chart for K: zero-size array to reduction operation maximum which has no identity
# Generating chart for NTRA...
# Generating chart for RWM...
# Generating chart for MRSN...
# Generating chart for XRAY...
# Error generating chart for XRAY: zero-size array to reduction operation maximum which has no identity
# Generating chart for SOXL...
# Error generating chart for SOXL: zero-size array to reduction operation maximum which has no identity
# Generating chart for REPL...
# Generating chart for AEVA...
# Generating chart for CNP...
# Error generating chart for CNP: zero-size array to reduction operation maximum which has no identity
# Generating chart for SNV...
# Generating chart for HPQ...
# Generating chart for VLTO...
# Generating chart for VYX...
# Generating chart for EEM...
# Generating chart for EIX...
# Generating chart for EOSE...
# Generating chart for LESL...
# Generating chart for ITUB...
# Generating chart for SPOT...
# Error generating chart for SPOT: zero-size array to reduction operation maximum which has no identity
# Generating chart for ADMA...
# Generating chart for APH...
# Generating chart for WBD...
# Generating chart for SBLK...
# Generating chart for SHAK...
# Generating chart for EVGO...
# Generating chart for WBA...
# Generating chart for BTU...
# Generating chart for INFY...
# Generating chart for BSV...
# Generating chart for RDFN...
# Generating chart for EPI...
# Generating chart for NTAP...
# Generating chart for BMY...
# Generating chart for MGNI...
# Generating chart for IP...
# Generating chart for BBAI...
# Generating chart for DYN...
# Error generating chart for DYN: zero-size array to reduction operation maximum which has no identity
# Generating chart for BHP...
# Generating chart for LUNR...
# Generating chart for RIOT...
# Generating chart for EXPD...
# Generating chart for TSLR...
# Generating chart for AA...
# Generating chart for DOV...
# Generating chart for SCHA...
# Generating chart for ROL...
# Generating chart for ARVN...
# Generating chart for UNP...
# Generating chart for GENI...
# Error generating chart for GENI: zero-size array to reduction operation maximum which has no identity
# Generating chart for BNDX...
# Generating chart for ECVT...
# Generating chart for EL...
# Error generating chart for EL: zero-size array to reduction operation maximum which has no identity
# Generating chart for BROS...
# Generating chart for EPAM...
# Generating chart for LEGN...
# Error generating chart for LEGN: zero-size array to reduction operation maximum which has no identity
# Generating chart for ESTC...
# Generating chart for MMC...
# Generating chart for ARKK...
# Generating chart for PNC...
# Generating chart for BAI...
# Generating chart for CVI...
# Generating chart for XOP...
# Generating chart for MLGO...
# Generating chart for AMZU...
# Generating chart for BB...
# Generating chart for OPTT...
# Generating chart for JBLU...
# Generating chart for XLP...
# Generating chart for XAIR...
# Generating chart for DHT...
# Generating chart for MGA...
# Generating chart for CLNE...
# Generating chart for VGIT...
# Generating chart for SMCX...
# Error generating chart for SMCX: zero-size array to reduction operation maximum which has no identity
# Generating chart for TSLA...
# Generating chart for SWK...
# Generating chart for LULU...
# Generating chart for KMI...
# Generating chart for ALMS...
# Generating chart for WEC...
# Generating chart for CWH...
# Generating chart for SW...
# Generating chart for NOG...
# Error generating chart for NOG: zero-size array to reduction operation maximum which has no identity
# Generating chart for SHO...
# Generating chart for FLYW...
# Generating chart for BLDP...
# Generating chart for GEO...
# Generating chart for SBH...
# Generating chart for TOL...
# Generating chart for MPC...
# Generating chart for ENVX...
# Generating chart for TSLG...
# Error generating chart for TSLG: zero-size array to reduction operation maximum which has no identity
# Generating chart for HSIC...
# Generating chart for VGSH...
# Error generating chart for VGSH: zero-size array to reduction operation maximum which has no identity
# Generating chart for TSLL...
# Generating chart for INDA...
# Generating chart for ALK...
# Generating chart for NEOG...
# Error generating chart for NEOG: zero-size array to reduction operation maximum which has no identity
# Generating chart for ROIV...
# Generating chart for ICE...
# Generating chart for AQN...
# Generating chart for JETS...
# Generating chart for ACWV...
# Generating chart for XBI...
# Generating chart for ASHR...
# Generating chart for VTIP...
# Error generating chart for VTIP: zero-size array to reduction operation maximum which has no identity
# Generating chart for UNG...
# Generating chart for OKTA...
# Generating chart for AMDL...
# Generating chart for NVDL...
# Generating chart for EMR...
# Generating chart for MBLY...
# Generating chart for SNDX...
# Generating chart for LXP...
# Generating chart for LYV...
# Generating chart for COMM...
# Generating chart for GGB...
# Generating chart for PUMP...
# Generating chart for INDI...
# Generating chart for BP...
# Generating chart for TSLT...
# Generating chart for KO...
# Generating chart for ASX...
# Generating chart for IR...
# Generating chart for JANX...
# Generating chart for PBR...
# Generating chart for CNI...
# Generating chart for FOUR...
# Generating chart for AXL...
# Generating chart for WRB...
# Generating chart for CG...
# Generating chart for APA...
# Error generating chart for APA: zero-size array to reduction operation maximum which has no identity
# Generating chart for FLEX...
# Generating chart for PBR-A...
# Generating chart for CALF...
# Generating chart for SMTC...
# Generating chart for SPEM...
# Generating chart for SHEL...
# Generating chart for DIS...
# Generating chart for MAT...
# Generating chart for WTI...
# Error generating chart for WTI: zero-size array to reduction operation maximum which has no identity
# Generating chart for FIVN...
# Generating chart for NAT...
# Generating chart for MAGS...
# Generating chart for MDB...
# Generating chart for SUZ...
# Generating chart for OCUL...
# Generating chart for QSR...
# Generating chart for TALO...
# Generating chart for AMBP...
# Generating chart for PBF...
# Error generating chart for PBF: zero-size array to reduction operation maximum which has no identity
# Generating chart for SPCE...
# Error generating chart for SPCE: zero-size array to reduction operation maximum which has no identity
# c:\Users\maxw2\Desktop\quanticon\.venv\Lib\site-packages\mplfinance\plotting.py:476: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure()
# Generating chart for NWL...
# Generating chart for QQQI...
# Generating chart for SCHO...
# Error generating chart for SCHO: zero-size array to reduction operation maximum which has no identity
# Generating chart for RCAT...
# Generating chart for CSTM...
# Generating chart for HPE...
# Generating chart for VTWO...
# Generating chart for GTM...
# Generating chart for VUZI...
# Generating chart for AMPX...
# Generating chart for TMUS...
# Generating chart for SO...
# Generating chart for ARBE...
# Generating chart for DVAX...
# Generating chart for DTE...
# Generating chart for ASAN...
# Generating chart for SQQQ...
# Generating chart for ARWR...
# Generating chart for DUK...
# Generating chart for SRAD...
# Error generating chart for SRAD: zero-size array to reduction operation maximum which has no identity
# Generating chart for ULTY...
# Generating chart for CIFR...
# Generating chart for NKE...
# Generating chart for AM...
# Generating chart for EMXC...
# Generating chart for TEM...
# Generating chart for DDOG...
# Generating chart for ONDS...
# Generating chart for PLUG...
# Generating chart for AAOI...
# Generating chart for SHY...
# Error generating chart for SHY: zero-size array to reduction operation maximum which has no identity
# Generating chart for STEP...
# Generating chart for ARRY...
# Generating chart for CGNX...
# Generating chart for ROKU...
# Generating chart for NVDU...
# Generating chart for PL...
# Generating chart for ET...
# Generating chart for HOG...
# Error generating chart for HOG: zero-size array to reduction operation maximum which has no identity
# Generating chart for ADC...
# Generating chart for USB...
# Generating chart for CE...
# Generating chart for IAS...
# Generating chart for PRCH...
# Generating chart for SRPT...
# Generating chart for WPC...
# Generating chart for FOXA...
# Generating chart for NVDX...
# Generating chart for MRK...
# Error generating chart for MRK: zero-size array to reduction operation maximum which has no identity
# Generating chart for BBY...
# Generating chart for SBUX...
# Generating chart for BIZD...
# Generating chart for PVH...
# Generating chart for AAL...
# Generating chart for APPS...
# Generating chart for PCVX...
# Generating chart for TGTX...
# Generating chart for IWM...
# Generating chart for DAWN...
# Generating chart for VIPS...
# Generating chart for HIVE...
# Generating chart for MTDR...
# Generating chart for REXR...
# Generating chart for AR...
# Generating chart for PCAR...
# Generating chart for PSNY...
# Generating chart for XRT...
# Generating chart for SLM...
# Generating chart for LSPD...
# Generating chart for NDAQ...
# Generating chart for RVMD...
# Generating chart for CVE...
# Generating chart for ARMK...
# Generating chart for RRC...
# Generating chart for LWLG...
# Generating chart for NTRS...
# Candlestick charts saved to ./outputs\2025-05-24_charts_quqd.pdf
